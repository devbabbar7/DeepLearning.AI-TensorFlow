# %% [markdown]
# <a href="https://colab.research.google.com/github/devbabbar7/DeepLearning.AI-TensorFlow/blob/main/Hello_world_in_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,), activation='linear'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='sgd')

# %%
x_train = []
y_train = []
for i in range(-5,6):
  x_train.append(i)
  y_train.append(i*2+1)
x_train = np.array(x_train)
y_train = np.array(y_train)
model.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 376ms/step - loss: 52.9875
# Epoch 2/200
# 1/1 [==============================] - 0s 9ms/step - loss: 18.3769
# Epoch 3/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.7422
# Epoch 4/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4398
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7923
# Epoch 6/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6948
# Epoch 7/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6298
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5715
# Epoch 9/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5184
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4703
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4266
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3868
# ...

# %%
# Test the model on some new data
x_test = [7,8]
y_test = [13, 15]
loss = model.evaluate(x_test, y_test)
print('Test loss:', loss)

# Use the model to predict the sum of two new numbers
x_new = [10,11]
#Prediction should be 21 and 23
y_new = model.predict(x_new)
print('Prediction:', y_new)
# Out:
# 1/1 [==============================] - 0s 43ms/step - loss: 3.9999
# Test loss: 3.9998607635498047
# 1/1 [==============================] - 0s 38ms/step
# Prediction: [[20.999968]
#  [22.999968]]
